# %%
import numpy as np, pandas as pd, polars as pl
from sklearn.model_selection import KFold
from sklearn import preprocessing as skp
from sklearn.decomposition import PCA 
import seaborn as sns

import xgboost as xgb
from sklearn.metrics import root_mean_squared_error as rmse
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('train.csv', index_col = 'id')
test = pd.read_csv('test.csv', index_col = 'id')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 750000 entries, 0 to 749999
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Podcast_Name                 750000 non-null  object
#  1   Episode_Title                750000 non-null  object
#  2   Episode_Length_minutes       662907 non-null  float64
#  3   Genre                        750000 non-null  object
#  4   Host_Popularity_percentage   750000 non-null  float64
#  5   Publication_Day              750000 non-null  object
#  6   Publication_Time             750000 non-null  object
#  7   Guest_Popularity_percentage  603970 non-null  float64
#  8   Number_of_Ads                749999 non-null  float64
#  9   Episode_Sentiment            750000 non-null  object
#  10  Listening_Time_minutes       750000 non-null  float64
# dtypes: float64(5), object(6)
# memory usage: 68.7+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250000 entries, 750000 to 999999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Podcast_Name                 250000 non-null  object
#  1   Episode_Title                250000 non-null  object
#  2   Episode_Length_minutes       221264 non-null  float64
#  3   Genre                        250000 non-null  object
#  4   Host_Popularity_percentage   250000 non-null  float64
#  5   Publication_Day              250000 non-null  object
#  6   Publication_Time             250000 non-null  object
#  7   Guest_Popularity_percentage  201168 non-null  float64
#  8   Number_of_Ads                250000 non-null  float64
#  9   Episode_Sentiment            250000 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 21.0+ MB

# %%
categorical_map = {
        'Monday': 0, 'Tuesday': 1, 'Wednesday': 2, 'Thursday': 3, 'Friday': 4, 'Saturday': 5, 'Sunday': 6, # Day

        'Morning': 0, 'Afternoon': 1, 'Evening': 2, 'Night': 3,                                            # Time

        'Negative': 0, 'Neutral': 1, 'Positive': 2,                                                        # Sentiment

        'True Crime': 0, 'Comedy': 1, 'Education': 2, 'Technology': 3, 'Health': 4, 'News': 5, 'Music': 6, # Genre
        'Sports': 7, 'Business': 8, 'Lifestyle': 9
        }

categories = ['Genre', 'Podcast_Name', 'Episode_Title', 'Publication_Day', 'Publication_Time', 'Episode_Sentiment']

# %%
podcast = {}
for i, n in enumerate(train['Podcast_Name'].unique()):
    podcast[n] = i

categorical_map.update(podcast)

# %%
train['Episode_Title'] = train['Episode_Title'].str[8:]
test['Episode_Title'] = test['Episode_Title'].str[8:]

# %%
train = train.replace(categorical_map).fillna(0)
test = test.replace(categorical_map).fillna(0)

# %%
x = train.drop('Listening_Time_minutes', axis=1)
y = train['Listening_Time_minutes']

# %%
poly = skp.PolynomialFeatures(interaction_only=True, include_bias=False)
x_poly = poly.fit_transform(x)
test_poly = poly.fit_transform(test)

# %%
cols = poly.get_feature_names_out(x.columns)
x = pd.DataFrame(x_poly, columns=cols)

test_cols = poly.get_feature_names_out(test.columns)
test = pd.DataFrame(test_poly, columns=test_cols)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 55 columns):
#  #   Column                                                  Non-Null Count   Dtype
# ---  ------                                                  --------------   -----
#  0   Podcast_Name                                            250000 non-null  float64
#  1   Episode_Title                                           250000 non-null  float64
#  2   Episode_Length_minutes                                  250000 non-null  float64
#  3   Genre                                                   250000 non-null  float64
#  4   Host_Popularity_percentage                              250000 non-null  float64
#  5   Publication_Day                                         250000 non-null  float64
#  6   Publication_Time                                        250000 non-null  float64
#  7   Guest_Popularity_percentage                             250000 non-null  float64
#  8   Number_of_Ads                                           250000 non-null  float64
#  9   Episode_Sentiment                                       250000 non-null  float64
#  10  Podcast_Name Episode_Title                              250000 non-null  float64
#  11  Podcast_Name Episode_Length_minutes                     250000 non-null  float64
#  12  Podcast_Name Genre                                      250000 non-null  float64
#  13  Podcast_Name Host_Popularity_percentage                 250000 non-null  float64
#  14  Podcast_Name Publication_Day                            250000 non-null  float64
#  15  Podcast_Name Publication_Time                           250000 non-null  float64
#  16  Podcast_Name Guest_Popularity_percentage                250000 non-null  float64
#  17  Podcast_Name Number_of_Ads                              250000 non-null  float64
#  18  Podcast_Name Episode_Sentiment                          250000 non-null  float64
#  19  Episode_Title Episode_Length_minutes                    250000 non-null  float64
#  20  Episode_Title Genre                                     250000 non-null  float64
#  21  Episode_Title Host_Popularity_percentage                250000 non-null  float64
#  22  Episode_Title Publication_Day                           250000 non-null  float64
#  23  Episode_Title Publication_Time                          250000 non-null  float64
#  24  Episode_Title Guest_Popularity_percentage               250000 non-null  float64
#  25  Episode_Title Number_of_Ads                             250000 non-null  float64
#  26  Episode_Title Episode_Sentiment                         250000 non-null  float64
#  27  Episode_Length_minutes Genre                            250000 non-null  float64
#  28  Episode_Length_minutes Host_Popularity_percentage       250000 non-null  float64
#  29  Episode_Length_minutes Publication_Day                  250000 non-null  float64
#  30  Episode_Length_minutes Publication_Time                 250000 non-null  float64
#  31  Episode_Length_minutes Guest_Popularity_percentage      250000 non-null  float64
#  32  Episode_Length_minutes Number_of_Ads                    250000 non-null  float64
#  33  Episode_Length_minutes Episode_Sentiment                250000 non-null  float64
#  34  Genre Host_Popularity_percentage                        250000 non-null  float64
#  35  Genre Publication_Day                                   250000 non-null  float64
#  36  Genre Publication_Time                                  250000 non-null  float64
#  37  Genre Guest_Popularity_percentage                       250000 non-null  float64
#  38  Genre Number_of_Ads                                     250000 non-null  float64
#  39  Genre Episode_Sentiment                                 250000 non-null  float64
#  40  Host_Popularity_percentage Publication_Day              250000 non-null  float64
#  41  Host_Popularity_percentage Publication_Time             250000 non-null  float64
#  42  Host_Popularity_percentage Guest_Popularity_percentage  250000 non-null  float64
#  43  Host_Popularity_percentage Number_of_Ads                250000 non-null  float64
#  44  Host_Popularity_percentage Episode_Sentiment            250000 non-null  float64
#  45  Publication_Day Publication_Time                        250000 non-null  float64
#  46  Publication_Day Guest_Popularity_percentage             250000 non-null  float64
#  47  Publication_Day Number_of_Ads                           250000 non-null  float64
#  48  Publication_Day Episode_Sentiment                       250000 non-null  float64
#  49  Publication_Time Guest_Popularity_percentage            250000 non-null  float64
#  50  Publication_Time Number_of_Ads                          250000 non-null  float64
#  51  Publication_Time Episode_Sentiment                      250000 non-null  float64
#  52  Guest_Popularity_percentage Number_of_Ads               250000 non-null  float64
#  53  Guest_Popularity_percentage Episode_Sentiment           250000 non-null  float64
#  54  Number_of_Ads Episode_Sentiment                         250000 non-null  float64
# dtypes: float64(55)
# memory usage: 104.9 MB

# %%
#x = x.iloc[:,:23]
#test = test.iloc[:,:23]

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 55 columns):
#  #   Column                                                  Non-Null Count   Dtype
# ---  ------                                                  --------------   -----
#  0   Podcast_Name                                            750000 non-null  float64
#  1   Episode_Title                                           750000 non-null  float64
#  2   Episode_Length_minutes                                  750000 non-null  float64
#  3   Genre                                                   750000 non-null  float64
#  4   Host_Popularity_percentage                              750000 non-null  float64
#  5   Publication_Day                                         750000 non-null  float64
#  6   Publication_Time                                        750000 non-null  float64
#  7   Guest_Popularity_percentage                             750000 non-null  float64
#  8   Number_of_Ads                                           750000 non-null  float64
#  9   Episode_Sentiment                                       750000 non-null  float64
#  10  Podcast_Name Episode_Title                              750000 non-null  float64
#  11  Podcast_Name Episode_Length_minutes                     750000 non-null  float64
#  12  Podcast_Name Genre                                      750000 non-null  float64
#  13  Podcast_Name Host_Popularity_percentage                 750000 non-null  float64
#  14  Podcast_Name Publication_Day                            750000 non-null  float64
#  15  Podcast_Name Publication_Time                           750000 non-null  float64
#  16  Podcast_Name Guest_Popularity_percentage                750000 non-null  float64
#  17  Podcast_Name Number_of_Ads                              750000 non-null  float64
#  18  Podcast_Name Episode_Sentiment                          750000 non-null  float64
#  19  Episode_Title Episode_Length_minutes                    750000 non-null  float64
#  20  Episode_Title Genre                                     750000 non-null  float64
#  21  Episode_Title Host_Popularity_percentage                750000 non-null  float64
#  22  Episode_Title Publication_Day                           750000 non-null  float64
#  23  Episode_Title Publication_Time                          750000 non-null  float64
#  24  Episode_Title Guest_Popularity_percentage               750000 non-null  float64
#  25  Episode_Title Number_of_Ads                             750000 non-null  float64
#  26  Episode_Title Episode_Sentiment                         750000 non-null  float64
#  27  Episode_Length_minutes Genre                            750000 non-null  float64
#  28  Episode_Length_minutes Host_Popularity_percentage       750000 non-null  float64
#  29  Episode_Length_minutes Publication_Day                  750000 non-null  float64
#  30  Episode_Length_minutes Publication_Time                 750000 non-null  float64
#  31  Episode_Length_minutes Guest_Popularity_percentage      750000 non-null  float64
#  32  Episode_Length_minutes Number_of_Ads                    750000 non-null  float64
#  33  Episode_Length_minutes Episode_Sentiment                750000 non-null  float64
#  34  Genre Host_Popularity_percentage                        750000 non-null  float64
#  35  Genre Publication_Day                                   750000 non-null  float64
#  36  Genre Publication_Time                                  750000 non-null  float64
#  37  Genre Guest_Popularity_percentage                       750000 non-null  float64
#  38  Genre Number_of_Ads                                     750000 non-null  float64
#  39  Genre Episode_Sentiment                                 750000 non-null  float64
#  40  Host_Popularity_percentage Publication_Day              750000 non-null  float64
#  41  Host_Popularity_percentage Publication_Time             750000 non-null  float64
#  42  Host_Popularity_percentage Guest_Popularity_percentage  750000 non-null  float64
#  43  Host_Popularity_percentage Number_of_Ads                750000 non-null  float64
#  44  Host_Popularity_percentage Episode_Sentiment            750000 non-null  float64
#  45  Publication_Day Publication_Time                        750000 non-null  float64
#  46  Publication_Day Guest_Popularity_percentage             750000 non-null  float64
#  47  Publication_Day Number_of_Ads                           750000 non-null  float64
#  48  Publication_Day Episode_Sentiment                       750000 non-null  float64
#  49  Publication_Time Guest_Popularity_percentage            750000 non-null  float64
#  50  Publication_Time Number_of_Ads                          750000 non-null  float64
#  51  Publication_Time Episode_Sentiment                      750000 non-null  float64
#  52  Guest_Popularity_percentage Number_of_Ads               750000 non-null  float64
#  53  Guest_Popularity_percentage Episode_Sentiment           750000 non-null  float64
#  54  Number_of_Ads Episode_Sentiment                         750000 non-null  float64
# dtypes: float64(55)
# memory usage: 314.7 MB

# %%
for c in categories: 
    x[c] = x[c].astype('category')
    test[c] = test[c].astype('category')

# %%
K = 3
kf = KFold(K, shuffle=True, random_state=55)

# %%
pred = pd.DataFrame()
pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
for train_idx, val_idx in kf.split(x,y):
    x_t, y_t = x.iloc[train_idx], y.iloc[train_idx]
    x_v, y_v = x.iloc[val_idx], y.iloc[val_idx]
    model = xgb.XGBRegressor(objective='reg:squarederror', eval_metric = 'rmse', enable_categorical = True, device = 'cuda', tree_method="hist")#, min_child_weight=4)
    model.fit(x_t, y_t, eval_set=[(x_v,y_v)])
    pred = pd.concat([pd.DataFrame(model.predict(test)), pred], axis=1)
    weight = model.get_booster().get_score(importance_type='weight')
    gain = model.get_booster().get_score(importance_type='total_gain')
    fi_dict = {'x': x.columns, 'importance': model.feature_importances_}
    fi_df = pd.DataFrame(fi_dict).sort_values(by='x')
    weight = pd.DataFrame(sorted(weight.items()))
    gain = pd.DataFrame(sorted(gain.items()))
# Out:
# [0]	validation_0-rmse:21.21501
# [1]	validation_0-rmse:17.61298
# [2]	validation_0-rmse:15.53115
# [3]	validation_0-rmse:14.39418
# [4]	validation_0-rmse:13.79195
# [5]	validation_0-rmse:13.47590
# [6]	validation_0-rmse:13.31154
# [7]	validation_0-rmse:13.22468
# [8]	validation_0-rmse:13.17613
# [9]	validation_0-rmse:13.14977
# [10]	validation_0-rmse:13.13323
# [11]	validation_0-rmse:13.12482
# [12]	validation_0-rmse:13.12126
# [13]	validation_0-rmse:13.11649
# [14]	validation_0-rmse:13.11496
# [15]	validation_0-rmse:13.11337
# [16]	validation_0-rmse:13.10926
# [17]	validation_0-rmse:13.10797
# [18]	validation_0-rmse:13.10417
# [19]	validation_0-rmse:13.10143
# [20]	validation_0-rmse:13.10065
# [21]	validation_0-rmse:13.10009
# [22]	validation_0-rmse:13.09861
# [23]	validation_0-rmse:13.09695
# [24]	validation_0-rmse:13.09719
# [25]	validation_0-rmse:13.09936
# [26]	validation_0-rmse:13.09812
# [27]	validation_0-rmse:13.09747
# [28]	validation_0-rmse:13.09523
# [29]	validation_0-rmse:13.09518
# [30]	validation_0-rmse:13.09613
# [31]	validation_0-rmse:13.09398
# [32]	validation_0-rmse:13.09231
# [33]	validation_0-rmse:13.09291
# [34]	validation_0-rmse:13.09227
# [35]	validation_0-rmse:13.09154
# [36]	validation_0-rmse:13.09205
# [37]	validation_0-rmse:13.09320
# [38]	validation_0-rmse:13.09463
# [39]	validation_0-rmse:13.09435
# [40]	validation_0-rmse:13.09301
# [41]	validation_0-rmse:13.09316
# [42]	validation_0-rmse:13.09225
# [43]	validation_0-rmse:13.09160
# [44]	validation_0-rmse:13.09162
# [45]	validation_0-rmse:13.09166
# [46]	validation_0-rmse:13.09204
# [47]	validation_0-rmse:13.09338
# [48]	validation_0-rmse:13.09506
# [49]	validation_0-rmse:13.09424
# [50]	validation_0-rmse:13.09546
# [51]	validation_0-rmse:13.09762
# [52]	validation_0-rmse:13.09900
# [53]	validation_0-rmse:13.09803
# [54]	validation_0-rmse:13.09819
# [55]	validation_0-rmse:13.09969
# [56]	validation_0-rmse:13.10022
# [57]	validation_0-rmse:13.10059
# [58]	validation_0-rmse:13.10051
# [59]	validation_0-rmse:13.10214
# [60]	validation_0-rmse:13.10247
# [61]	validation_0-rmse:13.10065
# [62]	validation_0-rmse:13.09999
# [63]	validation_0-rmse:13.10136
# [64]	validation_0-rmse:13.10155
# [65]	validation_0-rmse:13.10199
# [66]	validation_0-rmse:13.10156
# [67]	validation_0-rmse:13.10329
# [68]	validation_0-rmse:13.10332
# [69]	validation_0-rmse:13.10346
# [70]	validation_0-rmse:13.10530
# [71]	validation_0-rmse:13.10615
# [72]	validation_0-rmse:13.10707
# [73]	validation_0-rmse:13.10740
# [74]	validation_0-rmse:13.10794
# [75]	validation_0-rmse:13.10866
# [76]	validation_0-rmse:13.10849
# [77]	validation_0-rmse:13.10970
# [78]	validation_0-rmse:13.11048
# [79]	validation_0-rmse:13.11329
# [80]	validation_0-rmse:13.11417
# [81]	validation_0-rmse:13.11455
# [82]	validation_0-rmse:13.11573
# [83]	validation_0-rmse:13.11775
# [84]	validation_0-rmse:13.11882
# [85]	validation_0-rmse:13.11900
# [86]	validation_0-rmse:13.11995
# [87]	validation_0-rmse:13.11988
# [88]	validation_0-rmse:13.11955
# [89]	validation_0-rmse:13.11945
# [90]	validation_0-rmse:13.12060
# [91]	validation_0-rmse:13.12056
# [92]	validation_0-rmse:13.12233
# [93]	validation_0-rmse:13.12284
# [94]	validation_0-rmse:13.12334
# [95]	validation_0-rmse:13.12383
# [96]	validation_0-rmse:13.12457
# [97]	validation_0-rmse:13.12588
# [98]	validation_0-rmse:13.12741
# [99]	validation_0-rmse:13.12561
# [0]	validation_0-rmse:21.19995
# [1]	validation_0-rmse:17.59004
# [2]	validation_0-rmse:15.49987
# [3]	validation_0-rmse:14.35327
# [4]	validation_0-rmse:13.74305
# [5]	validation_0-rmse:13.42587
# [6]	validation_0-rmse:13.25440
# [7]	validation_0-rmse:13.16610
# [8]	validation_0-rmse:13.11783
# [9]	validation_0-rmse:13.09246
# [10]	validation_0-rmse:13.07393
# [11]	validation_0-rmse:13.06201
# [12]	validation_0-rmse:13.05532
# [13]	validation_0-rmse:13.05118
# [14]	validation_0-rmse:13.04937
# [15]	validation_0-rmse:13.04737
# [16]	validation_0-rmse:13.04453
# [17]	validation_0-rmse:13.04133
# [18]	validation_0-rmse:13.04006
# [19]	validation_0-rmse:13.04209
# [20]	validation_0-rmse:13.04090
# [21]	validation_0-rmse:13.03978
# [22]	validation_0-rmse:13.03725
# [23]	validation_0-rmse:13.03615
# [24]	validation_0-rmse:13.03636
# [25]	validation_0-rmse:13.03618
# [26]	validation_0-rmse:13.03642
# [27]	validation_0-rmse:13.03387
# [28]	validation_0-rmse:13.03378
# [29]	validation_0-rmse:13.03190
# [30]	validation_0-rmse:13.03207
# [31]	validation_0-rmse:13.02990
# [32]	validation_0-rmse:13.03025
# [33]	validation_0-rmse:13.03048
# [34]	validation_0-rmse:13.02982
# [35]	validation_0-rmse:13.02969
# [36]	validation_0-rmse:13.03000
# [37]	validation_0-rmse:13.03053
# [38]	validation_0-rmse:13.03149
# [39]	validation_0-rmse:13.03105
# [40]	validation_0-rmse:13.03141
# [41]	validation_0-rmse:13.03217
# [42]	validation_0-rmse:13.03142
# [43]	validation_0-rmse:13.02870
# [44]	validation_0-rmse:13.02808
# [45]	validation_0-rmse:13.02743
# [46]	validation_0-rmse:13.02759
# [47]	validation_0-rmse:13.02846
# [48]	validation_0-rmse:13.02827
# [49]	validation_0-rmse:13.02941
# [50]	validation_0-rmse:13.03018
# [51]	validation_0-rmse:13.03002
# [52]	validation_0-rmse:13.03042
# [53]	validation_0-rmse:13.02995
# [54]	validation_0-rmse:13.03058
# [55]	validation_0-rmse:13.03136
# [56]	validation_0-rmse:13.03290
# [57]	validation_0-rmse:13.03253
# [58]	validation_0-rmse:13.03473
# [59]	validation_0-rmse:13.03496
# [60]	validation_0-rmse:13.03582
# [61]	validation_0-rmse:13.03463
# [62]	validation_0-rmse:13.03435
# [63]	validation_0-rmse:13.03526
# [64]	validation_0-rmse:13.03377
# [65]	validation_0-rmse:13.03488
# [66]	validation_0-rmse:13.03598
# [67]	validation_0-rmse:13.03623
# [68]	validation_0-rmse:13.03614
# [69]	validation_0-rmse:13.03643
# [70]	validation_0-rmse:13.03738
# [71]	validation_0-rmse:13.03829
# [72]	validation_0-rmse:13.03851
# [73]	validation_0-rmse:13.03884
# [74]	validation_0-rmse:13.03804
# [75]	validation_0-rmse:13.03853
# [76]	validation_0-rmse:13.03819
# [77]	validation_0-rmse:13.03892
# [78]	validation_0-rmse:13.03854
# [79]	validation_0-rmse:13.03926
# [80]	validation_0-rmse:13.03916
# [81]	validation_0-rmse:13.03912
# [82]	validation_0-rmse:13.03992
# [83]	validation_0-rmse:13.03976
# [84]	validation_0-rmse:13.03918
# [85]	validation_0-rmse:13.03957
# [86]	validation_0-rmse:13.03993
# [87]	validation_0-rmse:13.04167
# [88]	validation_0-rmse:13.04150
# [89]	validation_0-rmse:13.04135
# [90]	validation_0-rmse:13.04207
# [91]	validation_0-rmse:13.04224
# [92]	validation_0-rmse:13.04174
# [93]	validation_0-rmse:13.04147
# [94]	validation_0-rmse:13.04276
# [95]	validation_0-rmse:13.04370
# [96]	validation_0-rmse:13.04483
# [97]	validation_0-rmse:13.04697
# [98]	validation_0-rmse:13.04825
# [99]	validation_0-rmse:13.04798
# [0]	validation_0-rmse:21.29350
# [1]	validation_0-rmse:17.67032
# [2]	validation_0-rmse:15.57085
# [3]	validation_0-rmse:14.42124
# [4]	validation_0-rmse:13.81040
# [5]	validation_0-rmse:13.49263
# [6]	validation_0-rmse:13.32495
# [7]	validation_0-rmse:13.23490
# [8]	validation_0-rmse:13.18782
# [9]	validation_0-rmse:13.16032
# [10]	validation_0-rmse:13.14215
# [11]	validation_0-rmse:13.13328
# [12]	validation_0-rmse:13.12601
# [13]	validation_0-rmse:13.11976
# [14]	validation_0-rmse:13.11733
# [15]	validation_0-rmse:13.11517
# [16]	validation_0-rmse:13.11173
# [17]	validation_0-rmse:13.11010
# [18]	validation_0-rmse:13.10489
# [19]	validation_0-rmse:13.10202
# [20]	validation_0-rmse:13.10145
# [21]	validation_0-rmse:13.09776
# [22]	validation_0-rmse:13.09685
# [23]	validation_0-rmse:13.09827
# [24]	validation_0-rmse:13.09755
# [25]	validation_0-rmse:13.09721
# [26]	validation_0-rmse:13.09698
# [27]	validation_0-rmse:13.09783
# [28]	validation_0-rmse:13.09843
# [29]	validation_0-rmse:13.09574
# [30]	validation_0-rmse:13.09590
# [31]	validation_0-rmse:13.09626
# [32]	validation_0-rmse:13.09494
# [33]	validation_0-rmse:13.09424
# [34]	validation_0-rmse:13.09517
# [35]	validation_0-rmse:13.09290
# [36]	validation_0-rmse:13.09340
# [37]	validation_0-rmse:13.09420
# [38]	validation_0-rmse:13.09304
# [39]	validation_0-rmse:13.09323
# [40]	validation_0-rmse:13.09452
# [41]	validation_0-rmse:13.09480
# [42]	validation_0-rmse:13.09509
# [43]	validation_0-rmse:13.09536
# [44]	validation_0-rmse:13.09655
# [45]	validation_0-rmse:13.09577
# [46]	validation_0-rmse:13.09551
# [47]	validation_0-rmse:13.09654
# [48]	validation_0-rmse:13.09732
# [49]	validation_0-rmse:13.09702
# [50]	validation_0-rmse:13.09679
# [51]	validation_0-rmse:13.09566
# [52]	validation_0-rmse:13.09458
# [53]	validation_0-rmse:13.09411
# [54]	validation_0-rmse:13.09400
# [55]	validation_0-rmse:13.09453
# [56]	validation_0-rmse:13.09335
# [57]	validation_0-rmse:13.09365
# [58]	validation_0-rmse:13.09406
# [59]	validation_0-rmse:13.09493
# [60]	validation_0-rmse:13.09360
# [61]	validation_0-rmse:13.09253
# [62]	validation_0-rmse:13.09237
# [63]	validation_0-rmse:13.09229
# [64]	validation_0-rmse:13.09157
# [65]	validation_0-rmse:13.09203
# [66]	validation_0-rmse:13.09249
# [67]	validation_0-rmse:13.09305
# [68]	validation_0-rmse:13.09392
# [69]	validation_0-rmse:13.09432
# [70]	validation_0-rmse:13.09457
# [71]	validation_0-rmse:13.09535
# [72]	validation_0-rmse:13.09558
# [73]	validation_0-rmse:13.09644
# [74]	validation_0-rmse:13.09666
# [75]	validation_0-rmse:13.09676
# [76]	validation_0-rmse:13.09784
# [77]	validation_0-rmse:13.09717
# [78]	validation_0-rmse:13.09743
# [79]	validation_0-rmse:13.09696
# [80]	validation_0-rmse:13.09503
# [81]	validation_0-rmse:13.09711
# [82]	validation_0-rmse:13.09774
# [83]	validation_0-rmse:13.09773
# [84]	validation_0-rmse:13.09858
# [85]	validation_0-rmse:13.09980
# [86]	validation_0-rmse:13.09907
# [87]	validation_0-rmse:13.09897
# [88]	validation_0-rmse:13.09856
# [89]	validation_0-rmse:13.09919
# [90]	validation_0-rmse:13.09951
# [91]	validation_0-rmse:13.10095
# [92]	validation_0-rmse:13.10063
# [93]	validation_0-rmse:13.10203
# [94]	validation_0-rmse:13.10260
# [95]	validation_0-rmse:13.10321
# [96]	validation_0-rmse:13.10365
# [97]	validation_0-rmse:13.10423
# [98]	validation_0-rmse:13.10401
# [99]	validation_0-rmse:13.10475

# %%
missing = set(fi_df['x']) - set(weight[0])
print(missing)
# Out:
# {'Genre', 'Podcast_Name Genre'}

# %%
fi_df.drop([3,12], inplace=True)
fi_df['x'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 53 entries, 2 to 50
# Series name: x
# Non-Null Count  Dtype
# --------------  -----
# 53 non-null     object
# dtypes: object(1)
# memory usage: 848.0+ bytes

# %%
bars = pd.DataFrame(np.vstack([weight[1], gain[1], fi_df['importance']]), columns=gain[0], index=['weight','total gain', 'feature importance'])
#bars = pd.DataFrame(np.rot90(np.vstack([weight[1], gain[1], fi_df['importance']])), index=gain[0], columns=['weight','total gain', 'feature importance'])

# %%
bars
# Out:
# 0                   Episode_Length_minutes  \
# weight                        4.310000e+02
# total gain                    4.892746e+08
# feature importance            6.482457e-01
#
# 0                   Episode_Length_minutes Episode_Sentiment  \
# weight                                             92.000000
# total gain                                     634404.000000
# feature importance                                  0.003938
#
# 0                   Episode_Length_minutes Genre  \
# weight                                 43.000000
# total gain                          89650.414062
# feature importance                      0.001191
#
# 0                   Episode_Length_minutes Guest_Popularity_percentage  \
# weight                                                      131.00000
# total gain                                               585013.56250
# feature importance                                            0.00255
#
# 0                   Episode_Length_minutes Host_Popularity_percentage  \
# weight                                                   2.390000e+02
# total gain                                               3.165946e+06
# feature importance                                       7.564319e-03
#
# 0                   Episode_Length_minutes Number_of_Ads  \
# weight                                         78.000000
# total gain                                 464922.343750
# feature importance                              0.003404
#
# 0                   Episode_Length_minutes Publication_Day  \
# weight                                            91.00000
# total gain                                    302838.71875
# feature importance                                 0.00190
#
# 0                   Episode_Length_minutes Publication_Time  \
# weight                                            72.000000
# total gain                                    219159.140625
# feature importance                                 0.001738
#
# 0                   Episode_Sentiment  Episode_Title  ...  \
# weight                       6.000000   2.103000e+03  ...
# total gain               38816.968750   1.449070e+07  ...
# feature importance           0.003694   3.934726e-03  ...
#
# 0                   Podcast_Name Publication_Time  Publication_Day  \
# weight                                  10.000000         63.00000
# total gain                           24264.369141     282445.93750
# feature importance                       0.001386          0.00256
#
# 0                   Publication_Day Episode_Sentiment  \
# weight                                      13.000000
# total gain                               48227.921875
# feature importance                           0.002118
#
# 0                   Publication_Day Guest_Popularity_percentage  \
# weight                                                35.000000
# total gain                                         94216.710938
# feature importance                                     0.001537
#
# 0                   Publication_Day Number_of_Ads  \
# weight                                  12.000000
# total gain                          155411.812500
# feature importance                       0.007395
#
# 0                   Publication_Day Publication_Time  Publication_Time  \
# weight                                     14.000000         18.000000
# total gain                              34721.820312      54441.082031
# feature importance                          0.001416          0.001727
#
# 0                   Publication_Time Episode_Sentiment  \
# weight                                        7.000000
# total gain                                15990.226562
# feature importance                            0.001304
#
# 0                   Publication_Time Guest_Popularity_percentage  \
# weight                                                 31.000000
# total gain                                          94149.937500
# feature importance                                      0.001734
#
# 0                   Publication_Time Number_of_Ads
# weight                                    7.000000
# total gain                            26370.097656
# feature importance                        0.002151
#
# [3 rows x 53 columns]

# %%
fig, ax = plt.subplots(3, figsize=(20,50))
ax[0].barh(bars.columns, bars.iloc[0,:]) #sns.barplot(data=bars.iloc[0,:], orient='y', width=1, errorbar=None, color='r')
ax[1].barh(bars.columns, bars.iloc[1,:]) #sns.barplot(data=bars.iloc[1,:], orient='y', width=1, errorbar=None, color='b')
ax[2].barh(bars.columns, bars.iloc[2,:]) #sns.barplot(data=bars.iloc[2,:], orient='y', width=1, errorbar=None, color='y')
ax[0].set_title('weight')
ax[0].set_title('total gain')
ax[0].set_title('feature importance')
#ax.bar_label(ax.containers[0], fontsize=10, padding=2)
plt.show()

# %%
pred.reset_index(drop=True, inplace=True)
pred.index += 750000
pred_sum = pred.sum(axis=1) / K

# %%
pred.head()
# Out:
#                 0          0          0          0          0          0  \
# 750000  52.422321  52.161697  52.887894  53.774200  53.656181  53.514206
# 750001  18.618940  18.313286  18.225765  18.258863  18.470175  18.167280
# 750002  49.408112  50.371239  48.327209  48.148037  48.922752  48.777225
# 750003  78.056595  80.410545  83.023750  79.001389  82.482407  80.813400
# 750004  49.724411  49.096329  48.715485  48.357048  48.951626  49.196938
#
#                 0          0          0          0  ...          0          0  \
# 750000  53.341064  54.078854  52.930553  52.063507  ...  52.096928  54.374897
# 750001  17.675730  18.523539  18.341600  17.102133  ...  17.817486  17.623583
# 750002  47.703999  48.212605  49.463329  49.633575  ...  49.737312  49.978252
# 750003  78.928375  79.774796  75.693535  83.510269  ...  76.436401  79.674911
# 750004  47.605820  49.398361  48.267700  49.117085  ...  49.732430  49.098606
#
#                 0          0          0          0          0          0  \
# 750000  52.739147  53.164509  51.267963  51.915543  54.571411  54.525528
# 750001  18.589970  19.009201  18.661680  18.220932  18.621820  18.428267
# 750002  47.920681  46.594982  49.707146  49.549095  49.720924  49.119438
# 750003  79.389191  77.818634  82.324066  81.756889  78.519585  81.700142
# 750004  48.171635  48.400120  49.263012  49.253521  48.492901  49.603424
#
#                 0          0
# 750000  54.800144  54.264595
# 750001  18.445499  18.393614
# 750002  49.751686  50.421898
# 750003  78.213562  80.849266
# 750004  48.799591  49.454044
#
# [5 rows x 100 columns]

# %%
pred_sum.rename('Listening_Time_minutes', inplace=True)
pred_sum.head()
# Out:
# 750000    53.340137
# 750001    18.317774
# 750002    49.138416
# 750003    80.038475
# 750004    48.960129
# Name: Listening_Time_minutes, dtype: float32

# %%
pred_sum.to_csv('submission_2.csv', index_label='id')
